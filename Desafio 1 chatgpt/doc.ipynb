# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
loja1_df = pd.read_csv('loja1.txt')

# %%
loja1_agrupado_df = loja1_df.drop(columns=['Mês'])
loja1_agrupado_df = loja1_agrupado_df.groupby('Produto', as_index=False).agg({
    'Preço Unitário': 'mean',
    'Quantidade Vendida': 'sum',
    'Faturamento Total': 'sum'
})



sns.set(rc={'figure.figsize': (14,6)})
fig = sns.barplot(data=loja1_agrupado_df, x='Produto', y="Faturamento Total", hue="Produto", width=0.5, errorbar=None)
fig.set_title('LOJA 01', fontsize=10, loc='center')
for p in fig.patches:

    fig.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9),
                textcoords = 'offset points',
                fontsize=9)
    
sns.lineplot(data= loja1_agrupado_df, x='Produto', y='Faturamento Total')
display(loja1_agrupado_df)
# Out:
#            Produto  Preço Unitário  Quantidade Vendida  Faturamento Total
# 0             BCAA            80.0                 420              33600
# 1         Creatina            50.0                 270              13500
# 2        Glutamina            70.0                 330              23100
# 3              HMB            90.0                 150              13900
# 4  Multivitamínico            40.0                 510              20400
# 5          Omega 3            30.0                 720              21600
# 6  Proteína Vegana           160.0                 180              28800
# 7      Termogênico           120.0                 210              25200
# 8     Whey Protein           150.0                 570              85500
# 9              ZMA            65.0                 300              19500

# %%
vendas_janeiro_df = loja1_df.loc[loja1_df['Mês'] == 'Janeiro']
display(vendas_janeiro_df)
fig = sns.barplot(data=vendas_janeiro_df, x='Produto', y="Faturamento Total", hue="Produto", width=0.5, errorbar=None)

fig.set_title('Vendas Janeiro', fontsize=10, loc='center')

for c in fig.patches:
    fig.annotate(format(c.get_height(), '.2f'),
                 (c.get_x() + c.get_width() / 2., c.get_height()),
                 ha = 'center', va = 'center',
                 xytext = (0, 9),
                 textcoords = 'offset points')
# Out:
#            Produto  Preço Unitário  Quantidade Vendida      Mês  \
# 0     Whey Protein             150                 200  Janeiro
# 1             BCAA              80                 150  Janeiro
# 2         Creatina              50                 100  Janeiro
# 3        Glutamina              70                 120  Janeiro
# 4      Termogênico             120                  80  Janeiro
# 5  Multivitamínico              40                 180  Janeiro
# 6              HMB              90                  60  Janeiro
# 7          Omega 3              30                 250  Janeiro
# 8  Proteína Vegana             160                  70  Janeiro
# 9              ZMA              65                 110  Janeiro
#
#    Faturamento Total
# 0              30000
# 1              12000
# 2               5000
# 3               8400
# 4               9600
# 5               7200
# 6               5400
# 7               7500
# 8              11200
# 9               7150

# %%
vendas_fevereiro_df = loja1_df.loc[loja1_df['Mês'] == 'Fevereiro']
display(vendas_fevereiro_df)
fig = sns.barplot(data=vendas_fevereiro_df, x='Produto', y="Faturamento Total", hue="Produto", width=0.5, errorbar=None)
fig.set_title('Vendas Fevereiro', fontsize=10, loc='center')

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9),
                textcoords = 'offset points')
# Out:
#             Produto  Preço Unitário  Quantidade Vendida        Mês  \
# 10     Whey Protein             150                 180  Fevereiro
# 11             BCAA              80                 140  Fevereiro
# 12         Creatina              50                  90  Fevereiro
# 13        Glutamina              70                 110  Fevereiro
# 14      Termogênico             120                  70  Fevereiro
# 15  Multivitamínico              40                 170  Fevereiro
# 16              HMB              90                  50  Fevereiro
# 17          Omega 3              30                 240  Fevereiro
# 18  Proteína Vegana             160                  60  Fevereiro
# 19              ZMA              65                 100  Fevereiro
#
#     Faturamento Total
# 10              27000
# 11              11200
# 12               4500
# 13               7700
# 14               8400
# 15               6800
# 16               4500
# 17               7200
# 18               9600
# 19               6500

# %%
vendas_marco_df = loja1_df.loc[loja1_df['Mês'] == 'Março']
display(vendas_marco_df)
fig = sns.barplot(data=vendas_marco_df, x='Produto', y="Faturamento Total", hue="Produto", width=0.5, errorbar=None)
fig.set_title('Vendas Março', fontsize=10, loc='center')

for c in fig.patches:
    fig.annotate(format(c.get_height(), '.2f'),
                 (c.get_x() + c.get_width() / 2., c.get_height()),
                 ha = 'center', va = 'center',
                 xytext = (0,9),
                 textcoords= 'offset points')
# Out:
#             Produto  Preço Unitário  Quantidade Vendida    Mês  \
# 20     Whey Protein             150                 190  Março
# 21             BCAA              80                 130  Março
# 22         Creatina              50                  80  Março
# 23        Glutamina              70                 100  Março
# 24      Termogênico             120                  60  Março
# 25  Multivitamínico              40                 160  Março
# 26              HMB              90                  40  Março
# 27          Omega 3              30                 230  Março
# 28  Proteína Vegana             160                  50  Março
# 29              ZMA              65                  90  Março
#
#     Faturamento Total
# 20              28500
# 21              10400
# 22               4000
# 23               7000
# 24               7200
# 25               6400
# 26               4000
# 27               6900
# 28               8000
# 29               5850

# %% [markdown]
# TOTAL DE FATURAMENTO MENSAL

# %%
faturamento_janeiro = vendas_janeiro_df['Faturamento Total'].sum()
faturamento_fevereiro = vendas_fevereiro_df['Faturamento Total'].sum()
faturamento_marco = vendas_marco_df['Faturamento Total'].sum()
#print(f'faturamento Janeiro = R$ {faturamento_janeiro:.2f}, \nfaturamento Fevereiro = R$ {faturamento_fevereiro:.2f}, \nfaruamento março = R$ {faturamento_marco:.2f}')

faturamento ={
    'janeiro' : faturamento_janeiro,
    'fevereiro' : faturamento_fevereiro,
    'março' : faturamento_marco
}

faturamento_df = pd.DataFrame(list(faturamento.items()), columns = ['Mês', 'Faturamento'])
display(faturamento_df)

fig= sns.barplot(data= faturamento_df, x='Mês', y='Faturamento', width=0.5, hue='Mês')
fig.set(title='Relação de faturamentos')

for c in fig.patches:
    fig.annotate(format(c.get_height(), '.2f'),
                 (c.get_x() + c.get_width() / 2., c.get_height()),
                 ha = 'center', va= 'center',
                 xytext = (0,9),
                 textcoords= 'offset points')
    
sns.lineplot(faturamento_df, linewidth=3,)
# Out:
#          Mês  Faturamento
# 0    janeiro       103450
# 1  fevereiro        93400
# 2      março        88250
# <Axes: title={'center': 'Relação de faturamentos'}, xlabel='Mês', ylabel='Faturamento'>

# %%
faturamentos = [faturamento_janeiro, faturamento_fevereiro, faturamento_marco]

maior_faturamento = max(faturamentos)
print(maior_faturamento)
# Out:
# 103450

# %%
janeiro_fevereiro = faturamento_janeiro - faturamento_fevereiro
janeiro_marco = faturamento_janeiro - faturamento_marco
fevereiro_marco = faturamento_fevereiro - faturamento_marco
print(janeiro_fevereiro, janeiro_marco, fevereiro_marco)
# Out:
# 10050 15200 5150

# %% [markdown]
# Saber a porcentagem de queda

# %%
porcentagem_de_queda = [(maior_faturamento - faturamento) / maior_faturamento * 100 for faturamento in faturamentos]

for i, porcentagem in enumerate(porcentagem_de_queda):
    print(f'Faturamento {i+1}: {faturamentos[i]} - Queda de {porcentagem:.2f}% em relação ao maior faturamento.')
# Out:
# Faturamento 1: 103450 - Queda de 0.00% em relação ao maior faturamento.
# Faturamento 2: 93400 - Queda de 9.71% em relação ao maior faturamento.
# Faturamento 3: 88250 - Queda de 14.69% em relação ao maior faturamento.

# %%
loja2_df = pd.read_csv('loja2.txt')
display(loja2_df, loja1_df)
# Out:
#             Produto  Preço Unitário  Quantidade Vendida        Mês  \
# 0      Whey Protein             150                 180    Janeiro
# 1              BCAA              80                 140    Janeiro
# 2          Creatina              50                  90    Janeiro
# 3         Glutamina              70                 110    Janeiro
# 4       Termogênico             120                  70    Janeiro
# 5   Multivitamínico              40                 170    Janeiro
# 6               HMB              90                  50    Janeiro
# 7           Omega 3              30                 240    Janeiro
# 8   Proteína Vegana             160                  60    Janeiro
# 9               ZMA              65                 100    Janeiro
# 10     Whey Protein             150                 175  Fevereiro
# 11             BCAA              80                 135  Fevereiro
# 12         Creatina              50                  85  Fevereiro
# 13        Glutamina              70                 105  Fevereiro
# 14      Termogênico             120                  65  Fevereiro
# 15  Multivitamínico              40                 165  Fevereiro
# 16              HMB              90                  45  Fevereiro
# 17          Omega 3              30                 235  Fevereiro
# 18  Proteína Vegana             160                  55  Fevereiro
# 19              ZMA              65                  95  Fevereiro
# 20     Whey Protein             150                 185      Março
# 21             BCAA              80                 145      Março
# 22         Creatina              50                  95      Março
# 23        Glutamina              70                 115      Março
# 24      Termogênico             120                  75      Março
# 25  Multivitamínico              40                 155      Março
# 26              HMB              90                  55      Março
# 27          Omega 3              30                 225      Março
# 28  Proteína Vegana             160                  65      Março
# 29              ZMA              65                  85      Março
#
#     Faturamento Total
# 0               27000
# 1               11200
# 2                4500
# 3                7700
# 4                8400
# 5                6800
# 6                4500
# 7                7200
# 8                9600
# 9                6500
# 10              26250
# 11              10800
# 12               4250
# 13               7350
# 14               7800
# 15               6600
# 16               4050
# 17               7050
# 18               8800
# 19               6175
# 20              27750
# 21              11600
# 22               4750
# 23               7800
# 24               9000
# 25               6200
# 26               4950
# 27               6750
# 28              10400
# 29               5525
#             Produto  Preço Unitário  Quantidade Vendida        Mês  \
# 0      Whey Protein             150                 200    Janeiro
# 1              BCAA              80                 150    Janeiro
# 2          Creatina              50                 100    Janeiro
# 3         Glutamina              70                 120    Janeiro
# 4       Termogênico             120                  80    Janeiro
# 5   Multivitamínico              40                 180    Janeiro
# 6               HMB              90                  60    Janeiro
# 7           Omega 3              30                 250    Janeiro
# 8   Proteína Vegana             160                  70    Janeiro
# 9               ZMA              65                 110    Janeiro
# 10     Whey Protein             150                 180  Fevereiro
# 11             BCAA              80                 140  Fevereiro
# 12         Creatina              50                  90  Fevereiro
# 13        Glutamina              70                 110  Fevereiro
# 14      Termogênico             120                  70  Fevereiro
# 15  Multivitamínico              40                 170  Fevereiro
# 16              HMB              90                  50  Fevereiro
# 17          Omega 3              30                 240  Fevereiro
# 18  Proteína Vegana             160                  60  Fevereiro
# 19              ZMA              65                 100  Fevereiro
# 20     Whey Protein             150                 190      Março
# 21             BCAA              80                 130      Março
# 22         Creatina              50                  80      Março
# 23        Glutamina              70                 100      Março
# 24      Termogênico             120                  60      Março
# 25  Multivitamínico              40                 160      Março
# 26              HMB              90                  40      Março
# 27          Omega 3              30                 230      Março
# 28  Proteína Vegana             160                  50      Março
# 29              ZMA              65                  90      Março
#
#     Faturamento Total
# 0               30000
# 1               12000
# 2                5000
# 3                8400
# 4                9600
# 5                7200
# 6                5400
# 7                7500
# 8               11200
# 9                7150
# 10              27000
# 11              11200
# 12               4500
# 13               7700
# 14               8400
# 15               6800
# 16               4500
# 17               7200
# 18               9600
# 19               6500
# 20              28500
# 21              10400
# 22               4000
# 23               7000
# 24               7200
# 25               6400
# 26               4000
# 27               6900
# 28               8000
# 29               5850
